# %% [markdown]
# # Exercise 5
#
# Related Notes:
# - Chapter_05_File_IO
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/njc-cz2-2021/Materials/blob/main/Exercises/Exercise_05_File_IO.ipynb)

# %% [markdown]
# ## Exercise 5.1
#
# Write following list `s` into a text file `q1.txt` with each item occupying 1 line.
#
# >``` python
# >s = [chr(i) + '.txt' for i in range(ord('A'), ord('F'))]
# >```
#
# Use following command in Jupyter Notebook to open `q1.txt` to verify the content in the file.
#
# >`!notepad q1.txt`

# %%
#YOUR_CODE_HERE
s = [chr(i) + '.txt' for i in range(ord('A'), ord('F'))]
with open('q1.txt', 'w') as f:
    f.writelines(f'{item}\n' for item in s)
# !notepad q1.txt

# %% [markdown]
# ## Exercise 5.2
#
# For each line of text in `q1.txt`, generate an empty text file and name the file using that line of text. If file already exists, remove it before generating a new file.
#
# Use the following code to check if a file exists.
#
# >``` python
# >import os
# >if os.path.exists(file_path): pass
# >```
#
# Use following command in Jupyter Notebook to confirm that you have generated all files.
#
# >``` bash
# >!ls *.txt
# >```

# %%
#YOUR_CODE_HERE
import os

with open('q1.txt') as f:
    for line in f:
        filename = line.strip()
        if not os.path.exists(filename):
            open(filename, 'w').close()

# %% [markdown]
# ## Exercise 5.3
#
# Write code to generate all the positive integers up to $n$ that are perfect squares and save them in a text file called `PERFECT_SQUARES.TXT`. Note that each line within the file should contain one integer, and the last character within the file should be an end line character.

# %%
#YOUR_CODE_HERE
def perfect_squares(n):
    listOfNums = []
    if n<0:
        return listOfNums
    for i in range(n):
        if int(i**0.5)**2==i:
            listOfNums.append(i)
    return listOfNums

with open('PERFECT_SQUARES.TXT', 'w') as f:
    for num in perfect_squares(100):
        f.writelines(f'{num}\n')

# %% [markdown]
# ## Exercise 5.4
#
# Write code to generate all the positive integers from $n + 1$ to $n + m$, and then append them to the file used in Exercise 5.3. (Note, do not overwrite the perfect squares from Exercise 5.3)

# %%
#YOUR_CODE_HERE
def generator(n, m):
    return [num for num in range(n+1, n+m+1)]

with open('PERFECT_SQUARES.TXT', 'a') as f:
    for num in generator(1, 100):
        f.writelines(f'{num}\n')

# %% [markdown]
# ## Exercise 5.5
#
# A log of a certain boss fight from a certain game is stored inside the file `log_ex8.csv` under the folder `resources`. The csv file contains the following header.
#
# - `'Parse%'`  refers to the performance of the character relative to all other players in the world,
# - `'Name'` refers to the name of the character in the game,
# - `'Amount'`  refers to the amount of damage
# - `'iLvL'`  refers to the quality of the equipment the character is using,
# - `'iLvL%'` refers to the performance of the player relative to players with similar quality of equipment,
# - `'Active Time'` refers to the percentage of time spend by the character doing damage during the fight.
# - `'DPS'` refers to the amount of damage done per second in the fight.
#
# Your task is to:
#
# - Store the contents of the csv file into a list `records` where each element in the list is itself a list where the elements correspond to the `Parse%`,`Name`,`Amount`,`iLvL`,`iLvL%`,`Active Time`,`DPS` values for each line in the csv file.
# - Create an empty list called `player_name`.
# - iterate over each element of `records` appending the player names to `player_name`.
# - Print each name in `player_name` in alphabetical order.

# %%
#YOUR_CODE_HERE
import csv

with open('./resources/log_ex8.csv') as f:
    reader = csv.reader(f)
    records = [row for row in reader]
    player_name = []
    for data in records:
        if data[1] != 'Name':
            player_name.append(data[1])
    print(sorted(player_name))
# Out:
# ['Angers', 'Anothervc', 'Avey', 'Biraprie', 'Chrisfumi', 'Chrissinger', 'Darkietank', 'Dewgie', 'Ericlock', 'Exolaris', 'Fyrebird', 'Gamheals', 'Gdook', 'Haloxd', 'Jari', 'Keipra', 'Kieu', 'Knoxvegas', 'Kolhito', 'Lymos', 'Makotoase', 'Masachi', 'Masakins', 'NÃ³mi', 'Ovy', 'Paeldryth', 'Pappaslop', 'Plastral', 'Revtide', 'Spooknspell', 'Stormblast', 'Synesthetix', 'WÃ´es']

# %% [markdown]
# ## Exercise 5.6
#
# Download the file: https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
#
# Write code to read and store the contents of this comma separated file within a 2D List, $L$, such that $L[i]$ corresponds to the sample entry on the $i$-th line of the file, and $L[i][j]$ corresponds to the $j$-th value of the $i$-th entry.
# Print the contents of the 2D List to verify that you have stored the contents correctly.

# %%
#YOUR_CODE_HERE
import csv

with open('./resources/iris.data') as f:
    reader = csv.reader(f)
    data = [row for row in reader]
    print(data)
# Out:
# [['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], ['4.9', '3.0', '1.4', '0.2', 'Iris-setosa'], ['4.7', '3.2', '1.3', '0.2', 'Iris-setosa'], ['4.6', '3.1', '1.5', '0.2', 'Iris-setosa'], ['5.0', '3.6', '1.4', '0.2', 'Iris-setosa'], ['5.4', '3.9', '1.7', '0.4', 'Iris-setosa'], ['4.6', '3.4', '1.4', '0.3', 'Iris-setosa'], ['5.0', '3.4', '1.5', '0.2', 'Iris-setosa'], ['4.4', '2.9', '1.4', '0.2', 'Iris-setosa'], ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa'], ['5.4', '3.7', '1.5', '0.2', 'Iris-setosa'], ['4.8', '3.4', '1.6', '0.2', 'Iris-setosa'], ['4.8', '3.0', '1.4', '0.1', 'Iris-setosa'], ['4.3', '3.0', '1.1', '0.1', 'Iris-setosa'], ['5.8', '4.0', '1.2', '0.2', 'Iris-setosa'], ['5.7', '4.4', '1.5', '0.4', 'Iris-setosa'], ['5.4', '3.9', '1.3', '0.4', 'Iris-setosa'], ['5.1', '3.5', '1.4', '0.3', 'Iris-setosa'], ['5.7', '3.8', '1.7', '0.3', 'Iris-setosa'], ['5.1', '3.8', '1.5', '0.3', 'Iris-setosa'], ['5.4', '3.4', '1.7', '0.2', 'Iris-setosa'], ['5.1', '3.7', '1.5', '0.4', 'Iris-setosa'], ['4.6', '3.6', '1.0', '0.2', 'Iris-setosa'], ['5.1', '3.3', '1.7', '0.5', 'Iris-setosa'], ['4.8', '3.4', '1.9', '0.2', 'Iris-setosa'], ['5.0', '3.0', '1.6', '0.2', 'Iris-setosa'], ['5.0', '3.4', '1.6', '0.4', 'Iris-setosa'], ['5.2', '3.5', '1.5', '0.2', 'Iris-setosa'], ['5.2', '3.4', '1.4', '0.2', 'Iris-setosa'], ['4.7', '3.2', '1.6', '0.2', 'Iris-setosa'], ['4.8', '3.1', '1.6', '0.2', 'Iris-setosa'], ['5.4', '3.4', '1.5', '0.4', 'Iris-setosa'], ['5.2', '4.1', '1.5', '0.1', 'Iris-setosa'], ['5.5', '4.2', '1.4', '0.2', 'Iris-setosa'], ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa'], ['5.0', '3.2', '1.2', '0.2', 'Iris-setosa'], ['5.5', '3.5', '1.3', '0.2', 'Iris-setosa'], ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa'], ['4.4', '3.0', '1.3', '0.2', 'Iris-setosa'], ['5.1', '3.4', '1.5', '0.2', 'Iris-setosa'], ['5.0', '3.5', '1.3', '0.3', 'Iris-setosa'], ['4.5', '2.3', '1.3', '0.3', 'Iris-setosa'], ['4.4', '3.2', '1.3', '0.2', 'Iris-setosa'], ['5.0', '3.5', '1.6', '0.6', 'Iris-setosa'], ['5.1', '3.8', '1.9', '0.4', 'Iris-setosa'], ['4.8', '3.0', '1.4', '0.3', 'Iris-setosa'], ['5.1', '3.8', '1.6', '0.2', 'Iris-setosa'], ['4.6', '3.2', '1.4', '0.2', 'Iris-setosa'], ['5.3', '3.7', '1.5', '0.2', 'Iris-setosa'], ['5.0', '3.3', '1.4', '0.2', 'Iris-setosa'], ['7.0', '3.2', '4.7', '1.4', 'Iris-versicolor'], ['6.4', '3.2', '4.5', '1.5', 'Iris-versicolor'], ['6.9', '3.1', '4.9', '1.5', 'Iris-versicolor'], ['5.5', '2.3', '4.0', '1.3', 'Iris-versicolor'], ['6.5', '2.8', '4.6', '1.5', 'Iris-versicolor'], ['5.7', '2.8', '4.5', '1.3', 'Iris-versicolor'], ['6.3', '3.3', '4.7', '1.6', 'Iris-versicolor'], ['4.9', '2.4', '3.3', '1.0', 'Iris-versicolor'], ['6.6', '2.9', '4.6', '1.3', 'Iris-versicolor'], ['5.2', '2.7', '3.9', '1.4', 'Iris-versicolor'], ['5.0', '2.0', '3.5', '1.0', 'Iris-versicolor'], ['5.9', '3.0', '4.2', '1.5', 'Iris-versicolor'], ['6.0', '2.2', '4.0', '1.0', 'Iris-versicolor'], ['6.1', '2.9', '4.7', '1.4', 'Iris-versicolor'], ['5.6', '2.9', '3.6', '1.3', 'Iris-versicolor'], ['6.7', '3.1', '4.4', '1.4', 'Iris-versicolor'], ['5.6', '3.0', '4.5', '1.5', 'Iris-versicolor'], ['5.8', '2.7', '4.1', '1.0', 'Iris-versicolor'], ['6.2', '2.2', '4.5', '1.5', 'Iris-versicolor'], ['5.6', '2.5', '3.9', '1.1', 'Iris-versicolor'], ['5.9', '3.2', '4.8', '1.8', 'Iris-versicolor'], ['6.1', '2.8', '4.0', '1.3', 'Iris-versicolor'], ['6.3', '2.5', '4.9', '1.5', 'Iris-versicolor'], ['6.1', '2.8', '4.7', '1.2', 'Iris-versicolor'], ['6.4', '2.9', '4.3', '1.3', 'Iris-versicolor'], ['6.6', '3.0', '4.4', '1.4', 'Iris-versicolor'], ['6.8', '2.8', '4.8', '1.4', 'Iris-versicolor'], ['6.7', '3.0', '5.0', '1.7', 'Iris-versicolor'], ['6.0', '2.9', '4.5', '1.5', 'Iris-versicolor'], ['5.7', '2.6', '3.5', '1.0', 'Iris-versicolor'], ['5.5', '2.4', '3.8', '1.1', 'Iris-versicolor'], ['5.5', '2.4', '3.7', '1.0', 'Iris-versicolor'], ['5.8', '2.7', '3.9', '1.2', 'Iris-versicolor'], ['6.0', '2.7', '5.1', '1.6', 'Iris-versicolor'], ['5.4', '3.0', '4.5', '1.5', 'Iris-versicolor'], ['6.0', '3.4', '4.5', '1.6', 'Iris ...

# %% [markdown]
# ## Exercise 5.7
#
# Each line in the file at: http://itu.dk/people/pagh/sad12/primes1000000.txt represents a prime number below 1,000,000.
#
# Write a function that uses the above file to test if a given positive integer below 1,000,000 is a prime number. If the given numbers exceeds 1,000,000, then utilise a separate function to calculate if it is a prime.

# %%
#YOUR_CODE_HERE
def check_prime(n, divisor=2):
    if n<=2:
        return True
    if n % divisor == 0:
        return False
    if divisor*divisor > n:
        return True
    return check_prime(n, divisor+1)

n = input('Input a number: ')
with open('resources/primes1000000.txt') as f:
    if int(n)<=1000000:
        if n in f.read().split():
            print("This is prime")
        else:
            print("This is not prime")
    elif check_prime(int(n)):
        print('This is prime')
    else:
        print('This is not prime')
# Out:
# This is not prime

# %% [markdown]
# ## Exercise 5.8
#
# A mathematical equation $y=f(x)$ can be visualized on a cartesian plane as the set of all the points $(x,y)$ where $y=f(x)$. Write a code that
#
# 1. generates 100 points that satisfy the equation $y=x^2$ for $-10\leq x\leq 10$ (for simplicity, take the uniform spacing for the $x$-values of the points),and
# 2. saves them into a text file named `ex8_8.txt`. Each line in the file is of the form $(x,y)$,
# 3. load the points from `ex8_8.txt` and using the module `matplotlib`, show the plot.

# %%
#YOUR_CODE_HERE
points = []
for i in range(100):
    x = 
    y = x**2
    points.append((x, y))

with open('ex8_8.txt', 'w') as f:
    for point in points:
        f.writelines(f'{point}\n')

# %%
import matplotlib.pyplot as plt

with open('ex8_8.txt') as f:
    data = [point.strip() for point in f.readlines()]
    x = [float(point.split(',')[0].replace('(', '')) for point in data]
    y = [float(point.split(',')[1].replace(')', '')) for point in data]
    plt.scatter(x, y)
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Exercise 5.9
#
# A text file, `NOI_24_RESULT.txt` contains the results of the medallist recipients for the 24th National Olympiad in Informatics.
#
# Write a code to:
#
# - read the data from the text file,
# - store the school name and medal counts in a Python dictionary `medal_count` where the school name is the key and the associated value is a tuple of the form `(GOLD, SILVER, BRONZE)`,
# - print out the top 5 school with the highest number of medals won, regardless of the medal type.

# %%
#YOUR_CODE_HERE
import csv

with open('resources/NOI_24_RESULT.csv') as f:
    reader = csv.reader(f)
    data = [row for row in reader]
    medal_count = {}
    for result in data:
        if len(result)==1 and result!=[]: medalType = ['Gold', 'Silver', 'Bronze'].index(result[0])
        elif result!=[]:
            if len(result) == 3:
                school = result[2]
            else:
                school = result[1]
            if school not in medal_count:
                medal_count[school] = [0,0,0]
            medal_count[school][medalType]+=1
    medal_count = {school:tuple(medals) for school,medals in medal_count.items()}
    medals = [sum(medal) for medal in medal_count.values()]
    print(f'Top 5 schools with highest number of medals: ')
    for i in range(1,6):
        maximum = max(medals)
        print(f'{i}. {list(medal_count.keys())[medals.index(maximum)]}: {maximum}')
        del medal_count[list(medal_count.keys())[medals.index(maximum)]]
        medals.remove(maximum)
# Out:
# Top 5 schools with highest number of medals:
# 1.  NUS High School Of Mathematics And Science: 10
# 2.  Raffles Institution: 10
# 3.  Hwa Chong Institution: 10
# 4.  United World College South East Asia Dover Campus: 8
# 5.  Anglo-Chinese School Independent: 5

# %% [markdown]
# ## Exercise 5.10
#
# A text file, `MARKET_PRICES.TXT`, contains the in-game prices for 6 items, Widowbloom, Rising Glory, Marrowroot, Vigil's Torch, Nighshade and Spectral Flask of Power from 1 December 2020 to 3 March 2021. Each line contains tab-delimited data that shows the date and the prices (in copper coins) of the 6 items.
#
# Each line is in the format:
#
# >``` text
# >YYYY-MM-DD\tWIDOWBLOOM\tRISING_GLORY\t\MARROWROOT\tVIGILS_TORCH\tNIGHTSHADE\tSPECTRAL_FLASK_OF_POWER\n
# >```
#
# - The date is of the form `YYYY-MM-DD`, for example, `2020-12-03` is 3rd December, 2020.
# - WIDOWBLOOM, RISING_GLORY, MARROWROOT, VIGILS_TORCH, NIGHTSHADE, SPECTRAL_FLASK_OF_POWER are all integers.
# - `\t` represents the tab character
# - `\n` represents the newline character
#
# The text file is stored in ascending order of date and time.
#
# ### Task 1
#
# Write a program to:
#
# - read the price data from the text file,
# - for each of the 6 items:
#     - find the highest price and print this value,
#     - find the lowest price and print this value.
#
# ### Task 2
#
# Suppose you want to play the market by buying and selling the 6 items above, one way to decide on items to invest in is by using the mean and variance of the daily rate of returns of the items. The latter is used to quantify the risk of holding such item.
#
# For an item $j$,
# - the **daily rate of return** of day $i$ to $i+1$, denoted as $r_i$ is defined to be $$r_i=\frac{p_{i+1}-p_{i}}{p_i},$$ where $p_{i+1}$ and $p_i$ are prices of the item on day $i+1$ and day $i$ respectively,
# - the mean of the daily rate of returns, denoted as $\overline{r}$, is just $\frac{\sum r_i}{n}$, where $n$ is the number of daily rate of returns recorded,
# - the variance of the daily rate of returns is $$\frac{\sum{(r_i-\overline{r})^2}}{n},$$ where $\overline{r}$ is the mean of the daily rate of returns and again $n$ is the number of daily returns recorded.
#
# Write a program to:
#
# - for each of the 6 items:
#     - find the mean of the daily rate of return,
#     - find the variance of the daily rate of return.

# %%
#YOUR_CODE_HERE
import csv

with open('resources/MARKET_PRICES.txt') as f:
    data = [row for row in csv.reader(f, delimiter='\t')] # read and clean data
    priceDict = {data[0][i]: [int(data[m][i]) for m in range(1,len(data))] for i in range(1,7)} # organising data {game: [# prices #]}
    
    # print items
    for game in priceDict:
        print(f'For {game.split('_')[0]}:\n\thighest price: {max(priceDict[game])}\n\tlowest price: {min(priceDict[game])}')
# Out:
# For widowbloom:
# 	highest price: 14031
# 	lowest price: 3214
# For risingglory:
# 	highest price: 7679
# 	lowest price: 2000
# For marrowroot:
# 	highest price: 8677
# 	lowest price: 2402
# For vigilstorch:
# 	highest price: 10086
# 	lowest price: 1720
# For nightshade:
# 	highest price: 17227
# 	lowest price: 3214
# For flask:
# 	highest price: 206537
# 	lowest price: 62927

# %%
import matplotlib.pyplot as plt
import csv

with open('resources/MARKET_PRICES.txt') as f:
    data = [row for row in csv.reader(f, delimiter='\t')] # read and clean data
    priceDict = {data[0][count]: [int(data[index][count]) for index in range(1,len(data))] for count in range(1,7)} # organising data {game: [# prices #]}
    
    for game in priceDict:
        mean = sum(priceDict[game])/len(priceDict[game]) # finding mean

        # applying variance formula
        dailyReturnRates = [(priceDict[game][i+1] - priceDict[game][i])/priceDict[game][i] for i in range(len(priceDict[game])-1)]
        variance = sum([(returnRate - (sum(dailyReturnRates)/len(dailyReturnRates)))**2 for returnRate in dailyReturnRates])/len(dailyReturnRates)
        
        print(f'For {game.split('_')[0]}:\n\tmean: {mean}:\n\tvariance: {variance}')
# Out:
# For widowbloom:
# 	mean: 7451.043010752688:
# 	variance: 0.02283701672008389
# For risingglory:
# 	mean: 3612.0967741935483:
# 	variance: 0.0361999924827622
# For marrowroot:
# 	mean: 4343.956989247312:
# 	variance: 0.03562764658071405
# For vigilstorch:
# 	mean: 3559.3870967741937:
# 	variance: 0.027762880221427973
# For nightshade:
# 	mean: 6303.688172043011:
# 	variance: 0.017598279761829583
# For flask:
# 	mean: 102733.89247311828:
# 	variance: 0.004586176455299762

# %% [markdown]
# ## Exercise 5.11 Jovie/2025
#
# A csv file, `homedepot.csv`, contains the locations of all the Home Depot stores in the US.
#
# The file is 2018 rows long, and all text fields are quoted.
#
# For each store:
#
# - The first 2 columns provide the longtitude and latitude of the store respectively. (Not latitude and longtitude)
#
# - The third column is in the form "HD - `CITY` - Store `STORENO`", where `CITY` is the city where the store is located, and `STORENO` is the store number.
#
# - The fourth column is the address of the store, including its ZIP code.
#
# ### Task 1
#
# Write a program to:
#
# - Get user input of a city
# - Print the addresses of all home depots in that city

# %%
import csv

with open('resources/homedepot.csv') as f:
    data = [[item.replace('\n', "") for item in row] for row in csv.reader(f)]
    cities = set([row[2].split('-')[1].replace(' ', '') for row in data])
    print(data)

    inp = input("Enter city ples u bum: ").upper()
    while inp not in cities:
        input("Enter city ples u bum: ").upper()
    
    print('All the home depots in this city:')
    for row in data:
        print()
# Out:
# [['-149.874371', '61.181119', 'HD - ANCHORAGE - Store 1301', '515 E TUDOR ROADANCHORAGE, AK  99503(907) 563-9800'], ['-149.848077', '61.143424', 'HD - ANCHORAGE - Store 8940', '1715 ABBOTT ROADANCHORAGE, AK  99507(907) 644-5646'], ['-149.814411', '61.217629', 'HD - ANCHORAGE - Store 1302', '400 RODEO PLACEANCHORAGE, AK  99508(907) 276-2006'], ['-147.737252', '64.852227', 'HD - FAIRBANKS - Store 1303', '601 JOHANSEN EXPRESSWAYFAIRBANKS, AK  99701(907) 451-9003'], ['-134.481288', '58.35787', 'HD - JUNEAU - Store 8939', '5201 COMMERCIAL BLVDJUNEAU, AK  99801(907) 463-5034'], ['-151.235805', '60.560034', 'HD - KENAI - Store 8938', '10480 SPUR HIGHWAYKENAI, AK  99611(907) 283-2228'], ['-149.418668', '61.574109', 'HD - WASILLA - Store 1304', '1255 PALMER WASILLA HWYWASILLA, AK  99654(907) 357-8181'], ['-85.975311', '32.936597', 'HD - ALEXANDER CITY - Store 6889', '1460 HWY 280ALEXANDER CITY, AL  35010(256) 234-6399'], ['-86.729397', '33.53022', 'HD - BIRMINGHAM - Store 880', '7001 CRESTWOOD BLVDBIRMINGHAM, AL  35210(205) 595-7780'], ['-86.691064', '33.418863', 'HD - BIRMINGHAM - Store 875', '4995 HWY 280BIRMINGHAM, AL  35242(205) 995-9357'], ['-86.811223', '33.378263', 'HD - BIRMINGHAM - Store 881', '3670 GALLERIA CIRCLEBIRMINGHAM, AL  35244(205) 988-8141'], ['-87.900976', '30.655006', 'HD - DAPHNE - Store 863', '7100 HWY 90DAPHNE, AL  36526(251) 625-0890'], ['-87.00169', '34.55929', 'HD - DECATUR - Store 884', '1225 WIMBERLY DR SWDECATUR, AL  35603(256) 353-2031'], ['-85.427459', '31.246638', 'HD - DOTHAN - Store 808', '3489 ROSS CLARK CIRCLEDOTHAN, AL  36303(334) 677-2790'], ['-86.921615', '33.477209', 'HD - FAIRFIELD - Store 882', '6405 FLINTRIDGE DRIVEFAIRFIELD, AL  35064(205) 781-0110'], ['-87.628518', '34.835416', 'HD - FLORENCE - Store 8577', '351 SEVILLE STREETFLORENCE, AL  35630(256) 764-5037'], ['-87.682959', '30.372301', 'HD - FOLEY - Store 802', '2899 S MCKENZIE STREETFOLEY, AL  36535(251) 955-2401'], ['-86.601024', '34.741196', 'HD - HUNTSVILLE - Store 804', '1035 MEMORIAL PKWYHUNTSVILLE, AL  35801(256) 536-2216'], ['-86.566976', '34.644054', 'HD - HUNTSVILLE - Store 888', '10012 S MEMORIAL PKWYHUNTSVILLE, AL  35803(256) 881-8270'], ['-87.25376', '33.84516', 'HD - JASPER - Store 810', '1808 HIGHWAY 78 EJASPER, AL  35501(205) 221-0367'], ['-86.737581', '34.756052', 'HD - MADISON - Store 803', "4045 LAWSON'S RIDGE DRMADISON, AL  35757(256) 837-6658"], ['-88.134783', '30.674127', 'HD - MOBILE - Store 865', '851 MONT LIMAR DRMOBILE, AL  36609(251) 380-0017'], ['-88.225322', '30.674456', 'HD - MOBILE - Store 801', '755 SCHLLINGER RDMOBILE, AL  36695(251) 634-0351'], ['-86.132759', '32.357342', 'HD - MONTGOMERY - Store 813', '10655 CHANTILLY PKWYMONTGOMERY, AL  36117(334) 260-8702'], ['-86.220878', '32.350832', 'HD - MONTGOMERY - Store 883', '2312 EASTERN BLVDMONTGOMERY, AL  36117(334) 272-8552'], ['-85.406349', '32.619787', 'HD - OPELIKA - Store 816', '2190 TIGERTOWN PARKWAYOPELIKA, AL  36801(334) 737-0136'], ['-85.784446', '33.606226', 'HD - OXFORD - Store 866', '350 CRYSTAL WATER DRIVEOXFORD, AL  36203(256) 832-2279'], ['-86.810111', '33.284361', 'HD - PELHAM - Store 805', '3191 PELHAM PKWYPELHAM, AL  35124(205) 685-1837'], ['-86.273974', '33.608072', 'HD - PELL CITY - Store 818', '289 VAUGHAN LANEPELL CITY, AL  35125(205) 338-1070'], ['-85.007749', '32.45438', 'HD - PHENIX CITY - Store 817', '3784 HWY 280-431 NORTHPHENIX CITY, AL  36867(334) 297-2045'], ['-86.402139', '32.44992', 'HD - PRATTVILLE - Store 806', '2710 LEGENDS PARKWAYPRATTVILLE, AL  36066(334) 285-1693'], ['-86.010434', '34.667964', 'HD - SCOTTSBORO - Store 812', '24635 JOHN T REID PKWYSCOTTSBORO, AL  35768(256) 575-2100'], ['-86.285372', '33.172655', 'HD - SYLACAUGA - Store 809', '41310 US HWY 280SYLACAUGA, AL  35150(256) 245-4953'], ['-86.640895', '33.60045', 'HD - TRUSSVILLE - Store 887', '1600 GADSDEN HWYTRUSSVILLE, AL  35173(205) 661-9415'], ['-87.518868', '33.196761', 'HD - TUSCALOOSA - Store 877', '1601 13TH AVE EASTTUSCALOOSA, AL  35404(205) 633-2038 ...

# %% [markdown]
# ### Task 2
#
# Suppose you want to create a program to direct the user to the nearest Home Depot that
#
# The spherical distance between 2 points on Earth, with spherical coordinates $(\phi_1, \lambda_1)$ and $(\phi_2, \lambda_2)$ respectively, can be calculated using the haversine formula, where the distance $d$ is given by
#
# $$d = 2R \operatorname{ atan2}(\sqrt{a}, \sqrt{1-a}) $$
#
# where
# - $a = \sin^2(\frac{\Delta \phi}{2}) + \cos \phi_1 ⋅ \cos \phi_2 ⋅ \sin^2(\frac{\Delta\lambda}{2})$,  and
# - $\Delta \phi = \phi_2 - \phi_1$, $\Delta \lambda = \lambda_2 - \lambda_1$
# - $R$ is the Earth's radius (in km). (Take $R = 6371$)
#
# The $\operatorname{atan2}(y, x)$ function is used to find the angle between the positive $x$-axis and the ray from the origin $(0, 0)$ to $(x, y)$.
#
# <center>
#
# ![atan2.png](attachment:atan2.png)
#
# </center>
#
# The benefit of using $\operatorname{atan2}(y, x)$ instead of $\operatorname{atan}(\frac{y}{x})$ is that $\operatorname{atan}(\frac{y}{x})$ does not consider the quadrant that the point lies in.
#
# Take note that $\operatorname{atan2}()$ takes 2 arguments while $\operatorname{atan}()$ takes only 1 argument
#
# Here is a table to illustrate the differences.
#
# <center>
#
# |Points  |$\operatorname{atan}(\frac{y}{x})$  |$\operatorname{atan2}(y, x)$|
# |------  |-----------    |-----------|
# |$(1, 1)$  |$\frac\pi4$    |$\frac\pi4$|
# |$(-1, -1)$|$-\frac{3\pi}4$|$\frac\pi4$|
# |$(-1, 0)$ |$-\pi$         |$0$        |
# |$(1, 0)$  |$\pi$          |$0$        |
#
# </center>
#
# The `atan2()` function can be found in the `math` module in Python.
#
# Write a program to:
#
# - Get user input of coordinates.
#     - Coordinates will be entered as a string without parenthesis.
#     - e.g. `29.979174, 31.415926`
# - Find the 5 nearest Home Depot stores to the coordinates.
#     - Find the distance using the formula above.
#     - Remember to convert coordinates from degrees to radians.
# - Print the address of the Home Depot stores by distance in ascending order.

# %% [markdown]
# ## Exercise 5.11 Jovie/2025
#
# A csv file, `homedepot.csv`, contains the locations of all the Home Depot stores in the US.
#
# The file is 2018 rows long, and all text fields are quoted.
#
# For each store:
#
# - The first 2 columns provide the longtitude and latitude of the store respectively. (Not latitude and longtitude)
#
# - The third column is in the form "HD - `CITY` - Store `STORENO`", where `CITY` is the city where the store is located, and `STORENO` is the store number.
#
# - The fourth column is the address of the store, including its ZIP code.
#
# ### Task 1
#
# Write a program to:
#
# - Get user input of a city
# - Print the addresses of all home depots in that city

# %%
import csv

with open('./resources/homedepot.csv') as f:
    data = [[item.replace('\n','') for item in row] for row in csv.reader(f)]
    cities = set([row[2].split(' - ')[1] for row in data])
    city = input("Which city: ").upper()
    while city not in cities:
        city = input("Try again. Which city: ").upper()
    for item in data:
        if item[2].split(' - ')[1] == city: print(item[3])
# Out:
# 515 E TUDOR ROADANCHORAGE, AK  99503(907) 563-9800
# 1715 ABBOTT ROADANCHORAGE, AK  99507(907) 644-5646
# 400 RODEO PLACEANCHORAGE, AK  99508(907) 276-2006

# %% [markdown]
# ### Task 2
#
# Suppose you want to create a program to direct the user to the nearest Home Depot that
#
# The spherical distance between 2 points on Earth, with spherical coordinates $(\phi_1, \lambda_1)$ and $(\phi_2, \lambda_2)$ respectively, can be calculated using the haversine formula, where the distance $d$ is given by
#
# $$d = 2R \operatorname{ atan2}(\sqrt{a}, \sqrt{1-a}) $$
#
# where
# - $a = \sin^2(\frac{\Delta \phi}{2}) + \cos \phi_1 ⋅ \cos \phi_2 ⋅ \sin^2(\frac{\Delta\lambda}{2})$,  and
# - $\Delta \phi = \phi_2 - \phi_1$, $\Delta \lambda = \lambda_2 - \lambda_1$
# - $R$ is the Earth's radius (in km). (Take $R = 6371$)
#
# The $\operatorname{atan2}(y, x)$ function is used to find the angle between the positive $x$-axis and the ray from the origin $(0, 0)$ to $(x, y)$.
#
# <center>
#
# ![atan2.png](attachment:atan2.png)
#
# </center>
#
# The benefit of using $\operatorname{atan2}(y, x)$ instead of $\operatorname{atan}(\frac{y}{x})$ is that $\operatorname{atan}(\frac{y}{x})$ does not consider the quadrant that the point lies in.
#
# Take note that $\operatorname{atan2}()$ takes 2 arguments while $\operatorname{atan}()$ takes only 1 argument
#
# Here is a table to illustrate the differences.
#
# <center>
#
# |Points  |$\operatorname{atan}(\frac{y}{x})$  |$\operatorname{atan2}(y, x)$|
# |------  |-----------    |-----------|
# |$(1, 1)$  |$\frac\pi4$    |$\frac\pi4$|
# |$(-1, -1)$|$-\frac{3\pi}4$|$\frac\pi4$|
# |$(-1, 0)$ |$-\pi$         |$0$        |
# |$(1, 0)$  |$\pi$          |$0$        |
#
# </center>
#
# The `atan2()` function can be found in the `math` module in Python.
#
# Write a program to:
#
# - Get user input of coordinates.
#     - Coordinates will be entered as a string without parenthesis.
#     - e.g. `29.979174, 31.415926`
# - Find the 5 nearest Home Depot stores to the coordinates.
#     - Find the distance using the formula above.
#     - Remember to convert coordinates from degrees to radians.
# - Print the address of the Home Depot stores by distance in ascending order.

# %%
from math import atan2, sin, cos, sqrt, radians
import csv

with open('./resources/homedepot.csv') as f:
    data = [[item.replace('\n','') for item in row] for row in csv.reader(f)]
    coordsInput = tuple([radians(float(n)) for n in input("Give coords: ").split(', ')])
    distances = []

    for item in data:
        coords = tuple([radians(float(item[0])), radians(float(item[1]))])
        a = (sin(((coords[0]-coordsInput[0])/2))**2) + cos(coordsInput[0]) * cos(coords[0]) * (sin(((coords[1]-coordsInput[1])/2))**2)
        distances.append(2*6371*atan2(sqrt(a), sqrt((1-a))))
        
    for _ in range(5):
        minimum = min(distances)
        place = data[distances.index(minimum)][3]
        print(f'Address: {place} Distance: {minimum:.05f}')
        data.pop(distances.index(minimum))
        distances.pop(distances.index(minimum))
# Out:
# Address: 1-2 DONOE ROAD 4000ST THOMAS, VI  802(340) 777-1077 Distance: 10611.29598
# Address: 65TH INFANTRY AVE KM11.7CAROLINA, PR  979(787) 257-1555 Distance: 10722.19920
# Address: 133 65TH AVE BO SANCAROLINA, PR  983(787) 776-1000 Distance: 10727.74172
# Address: STATE HWY 52 AND SR 842SAN JUAN, PR  928(787) 731-1200 Distance: 10735.77208
# Address: LAS CATALINAS MALLCAGUAS, PR  726(787) 703-1400 Distance: 10735.83694
